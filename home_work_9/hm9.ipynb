# %% [markdown]
# # Урок 9. Инструменты разметки наборов данных
#
# ## Задание 1.
#
# Выберите датасет, который имеет отношение к вашей области интересов или исследований. Датасет должен содержать неструктурированные данные, требующие разметки для решения конкретной задачи, например, анализа настроений или распознавания именованных сущностей.
#
# взял Yelp Reviews Dataset  https://www.kaggle.com/datasets/omkarsabnis/yelp-reviews-dataset?select=yelp.csv

# %%
import pandas as pd
file_path = "yelp.csv"
yelp_dataset = pd.read_csv(file_path, encoding='utf-8')
yelp_dataset.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# ...

# %%
# возьмем только текст остальные поля нам не нужны
yelp = yelp_dataset['text']
yelp.head()
# Out:
# 0    My wife took me here on my birthday for breakf...
# 1    I have no idea why some people give bad review...
# 2    love the gyro plate. Rice is so good and I als...
# 3    Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 4    General Manager Scott Petello is a good egg!!!...
# Name: text, dtype: object

# %%
# сохраним
yelp.to_csv('cleaned_yelp.csv', index=False)

# %%
file_path = "cleaned_yelp.csv"
yelp_dataset = pd.read_csv(file_path, encoding='utf-8')
yelp_dataset.head()
# Out:
#                                                 text
# 0  My wife took me here on my birthday for breakf...
# 1  I have no idea why some people give bad review...
# 2  love the gyro plate. Rice is so good and I als...
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 4  General Manager Scott Petello is a good egg!!!...

# %% [markdown]
# Задание 2.
# Выполните разметку на основе правил (rule-based labeling) на подмножестве выбранного датасета. Разработайте и реализуйте набор правил или условий, которые позволят автоматически присваивать метки данным на основе определенных шаблонов или критериев.

# %%
def sentiment_analysis(text):
    """Определяет настроение текста positive , negaive neutral"""
    positive_keywords = ['good', 'great', 'excellent', 'positive', 'joy', 'happy', 'wonderful', 'amazing', 'very well', 'best','delish']
    negative_keywords = ['bad', 'terrible', 'disappointed', 'negative', 'problem', 'sad', 'negatively']
    text = text.lower()
    if any (keyword in text for keyword in positive_keywords):
        return 'positive'
    elif any(keyword in text for keyword in negative_keywords):
        return 'negative'
    else:
        return 'neutral'
    
# yelp.to_csv('auto_yelp.csv', index=False)

# %%
# применяем разметку на основе правила к случайному подмножеству датасета
labeled_data = yelp_dataset.sample(frac=0.2)  #  взятие 20% от всего датасета
labeled_data['label'] = labeled_data['text'].apply(sentiment_analysis)

# %% [markdown]
# Задача 3.
# Выполните разметку вручную отдельного подмножества выбранного датасета с помощью выбранного вами инструмента разметки.

# %%
# возьмем заполнный в label studio DataSet
manually_labeled_data = pd.read_csv('project-2-at-2024-08-12-20-15-972b4320.csv')

# %% [markdown]
# Задача 4.
# Объедините данные, размеченные вручную, с данными, размеченными на основе правил. Объедините два подмножества размеченных данных в один набор данных, сохранив при этом соответствующую структуру и целостность

# %%
#  объединение автоматически размеченных данных с ручной разметкой
combined_data = pd.concat([labeled_data, manually_labeled_data])

# %%
combined_data['sentiment'] = combined_data['sentiment'].fillna('neutral')

# %%
combined_data.head()
# Out:
#                                                    text     label  \
# 7576  The person before me reviewed Phoenix Greyhoun...  positive
# 9564  One star is far more than they deserve.  The o...   neutral
# 8369  Does YC's stand for "yucky chinese?" \n\nThat'...  positive
# 5989  I liked this place. Great Atmosphere and music...  positive
# 7537  Love sitting at the sushi bar, the chef's are ...   neutral
#
#       annotation_id  annotator created_at  id  lead_time sentiment updated_at
# 7576            NaN        NaN        NaN NaN        NaN   neutral        NaN
# 9564            NaN        NaN        NaN NaN        NaN   neutral        NaN
# 8369            NaN        NaN        NaN NaN        NaN   neutral        NaN
# 5989            NaN        NaN        NaN NaN        NaN   neutral        NaN
# 7537            NaN        NaN        NaN NaN        NaN   neutral        NaN

# %%
combined_data.to_csv('combi_yelp.csv', index=False)

# %% [markdown]
# Задача 5.
# Обучите модель машинного обучения, используя объединенный набор размеченных данных. Разделите датасет на обучающий и тестовый наборы и используйте обучающий набор для обучения модели.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = combined_data['text']
y = combined_data['sentiment']

# векторизация текста
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)
# разделение данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)
# cоздание и обучение модели логистической регрессии
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Задача 6.
# Оценить эффективность обученной модели на тестовом датасете. Используйте подходящие метрики оценки. Интерпретируйте результаты и проанализируйте эффективность модели в решении задачи разметки

# %%
from sklearn.metrics import accuracy_score
# Оценка модели
y_test_predicted = model.predict(X_test)
# оценка точности модели
accuracy = accuracy_score(y_test, y_test_predicted)
print(f'Точность модели: {accuracy}')
# Out:
# Точность модели: 0.9733009708737864
